# %%
"""quiz_1."""

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Список вопросов к видео https://youtu.be/hW_7hodGxVU?si=tCEVs00xGt2q61eW (АЛГОРИТМ ПРИНЯТИЯ И ОТДАЧИ ДОМАШКИ):
#
# (По желанию )В ответе подробно всё опишите и обязательно нужно указывать тайм код из видео где я это сказал, по желанию, дополнительно прикладываем скриншот из видео.
# Если вы знаете ответы на вопросы из Вашего опыта, то таймкоды из видео не надо указывать и т.д.
#
# 1) Как понять, что домашка пришла?
# Ответ: Появится сообщение в чате Homework, а так же в телеграмме появится дополнительно выделенное сообщение с твоим ником к примеру @Delyzyd.
# Далее заходим в github for windows обнавляем страницу и видим новый комит, его и берем в работу.
# 2) Как принять домашку?
# Ответ:Заходим в github for windows обнавляем страницу и видим новый комит, его и берем в работу.
# 3) Зачем нужна кнопка history и какие функции появляются при нажатии правой кнопки мыши на коммит?
# Ответ: 1-Увидедить какие были изменения ранее. Раньше я создавал новую папку прям в проекте, вкладывал туда скриншот или фотографию и потом просто прописывал в markdown путь до этой фото/скриншот и спокойно потом пушил все на репозиторий. Сейчас это делается как то по другому, но смысл остается тот же. Пока сделаю как говорит книжка, но боюсь что линтеры меня сожрут и в дополнение функции: копирование хеша комита, создание ветки, сравнение изменений
# 3.1) Где брать ссылку на коммит? куда её отправлять?
# Ответ: Жмешь правой кнопкой мыши на коммит, находишь функцию view github открываешь ссылку и копируешь ее.
# 4) Что такое файл лога?
# Ответ: Мы создали данный фаил чтобы записывать в него все наши действия(можно тезисно)
# 4.1) Когда нужно его пушить?
# Ответ: После каждого занятия
# 5) Что такое интерпритатор?
# Ответ: Программа, которая выполняет код Python построчно
# 6) Где можно выбрать интерпритатор?
# Ответ: В VS Code: Ctrl+Shift+P → "Python: Select Interpreter"
# 7) Что такое модуль?
# Ответ:Файл Python (.py), содержащий определения функций, классов и переменных
# 8) Как создать и отправить коммит?
# Ответ: Так как директорию мы скачали себе локально и попросили git отслеживать изменения,теперь внесении каких либо правок в VS code сообщает о возможных изменениях, а так же его страхует github for windows(кошка). Следовательно после внесения изменений необходимо провести проверку линтеров и если все ок то запушить в репо. Раньше я делал это всего 3-мы командами git add, git commit - m "бла бла бла", git push ссылка на репо
# 9) Как посмотреть что коммит точно отправлен и находится в github?
# Ответ: Через кошку view github откроется ссылка и там можно посмотреть на свой комит.
# 10) Какая команда показывает что код не прошёл проверки  ошибки?
# Ответ: В зависимости от линтера
# 10.1) Напишите список линтеров которые используются для проверки кода и дайте их краткую характеристику.
# Ответ:  Pylint - комплексная проверка качества кода
#         Flake8 - проверка на соответствие PEP8 и логические ошибки
#         Black - автоматическое форматирование кода
#         Mypy - проверка типов
#         Pydocstyle - проверка документации
# 11) Как узнать какой именно линтер не прошёл проверку?
# Ответ: в терминале выскакивает сообщение с кодом ошибки, стройкой, и название линтера.
# 12) Линтер Pylint видит markdown?
# Ответ: нет
# 13) Номер ячейки в терминале и номер ячейки в vs code может отличаться? в каком случае?
# Ответ: да, когда есть строки с языком markdown
# 14) Где посмотреть номер ячейки в vscode?
# Ответ: в правом нижнем углу Cell 3 of 3
# 15) В каком формате ipynb отправляется в гитхаб? причём здесь JSON?
# 16) Где посмотреть в какой ячейке ошибка?
# Ответ: Линтер сообщит о номере ячейки
# 17) Как запустить терминал?
# Ответ: В VS code в верхней панели найти кнопку терминал-> новый терминал
# 18) Что такое линтер?
# Ответ: Инструмент статического анализа кода для выявления ошибок, стилистических проблем и потенциальных багов
# 19) В какой сайт нужно вставлять код ошибки если ошибка связана с pylint?
# Ответ: https://www.pylint.org/
# 20) Секция pydocstyle в большинстве случае автоматический закрывается после исправления ошибок в каком линтере?
# Ответ: pylint
# 21) Что такое описание модуля? Оно должно отражать информацию о том что находится в модуле?
# Ответ: Описание модуля или файла, как правило еще применяется когда пишут функции, классы и библиотеки. В него включают описательную часть, т.е. что делает и для чего.
# 21) С какой  git команды начинается утро программиста?
# Ответ: git pull
# 22) После внесения изменений в файлах, кнопка open in vs code пропадает в кошке, как по другому открыть vs code из кошки?
# Ответ: Открыть комит, нажать правую кнопку мыши или 3 точки и в выпадающем меню выбрать нужную функцию
# 23) Что такое stash?
#   Общее объяснение концепции.
#   Ответ:
#   это временное хранилище Git для незакоммиченных изменений в рабочей директории. Позволяет быстро "спрятать" правки (включая изменения в отслеживаемых файлах и staged-файлах), чтобы:
#
# Переключиться на другую ветку без комита
#
# Обновить код (git pull)
#
# Проверить предыдущее состояние кода
#
# Сохранить незавершенную работу, не создавая коммит.
# 23.1) Как сохранить стэш?
#   git команда(подсказка: https://t.me/c/1937296927/3602/19531):
# Ответ: git stash push -m "Описание изменений"
#   Кнопка в vs code:
#   Ответ:
# Откройте панель Source Control (Ctrl+Shift+G).
#
# Нажмите на ... → Stash → Stash Changes...
#
# Введите описание
#
# 23.2) Как восстановить стэш(подсказка: https://t.me/c/1937296927/3602/25747)?:
#
#       git команда(подсказка: https://t.me/c/1937296927/3602/19531)?:
#       Ответ: git stash apply stash@{n} - Применяет конкретный стэш
#
# 23.3) Различие между стэшем и коммитом.
# Ответ: СТЭШ - это временная точка, а коммит уже постоянная
#   Когда лучше сохранить изменения в стэше, а когда коммитить.
#   Ответ: Когда нужно перейти на другую ветку
# 23.4) Как просмотреть список сохраненных стэшей?
#   git команда (подсказка: https://t.me/c/1937296927/3602/19531):
#   Ответ: git stash list
# 23.5) Как удалить стэш?
#   Команды для удаления отдельных стэшей или всех сразу.
#   git команда (подсказка: https://t.me/c/1937296927/3602/19531):
# Ответ: git stash drop stash@{n}
# 23.6) Практические примеры использования стэша.
#   Краткие сценарии, где стэш помогает.
# Ответ: Нужно переключится с задания на задание
# 24) Где посмотреть что есть конфликт в файлах?
# Ответ: Конфликтующие файлы помечаются красным значком U (Unmerged) в панели Source Control.
# 24.1) Когда он появляется?
# Ответ:
# Слиянии веток
# Применении стэша
# Перебазировании
# Пулле
# 25) Как решить конфликт в файлах?
# Ответ: Либо ручками, либо принять предложение от системы
# 26) Напишите правильное утверждение
# -Зелёное то что пришло с гитхаба и синее локальные изменения или синее то что пришло с гитхаба и зелёное это локальные изменения
# Ответ: Зелёное то что пришло с гитхаба и синее локальные изменения
# 27) Если мы работаем в одном файле, можно ли принять pull после того как вы спрячете в стэш свои изменения?
# Ответ: Да, можно и нужно. Порядок действий:
#
# git stash (прячет ваши незакоммиченные изменения).
#
# git pull (забирает изменения с удаленного репозитория).
#
# git stash pop (возвращает ваши спрятанные изменения обратно в рабочую директорию).
#
# 27.1) Что может произойти когда stash восстановите после принятия pull?
# Ответ: Конфликты слияния
# 28) Сколько способов решения конфликтов было показано в видео? Напишите ЧИСЛО и укажите их способы.
# Ответ: 3
# Принять входящие изменения.
# Принять исходящие изменения
# Принять оба изменения
# 29) Что делает кнопка complete merge?
# Ответ: Завершает слияние
# 30) В какой чат нужно писать если остались вопросы?
# Ответ: https://t.me/c/1937296927/2415
# 31) Что такое FORK? Зачем его делают?
# Ответ: это полная копия чужого репозитория на вашем собственном аккаунте на GitHub/GitLab/Bitbucket и т.д. Вы становитесь владельцем этой копии
# 32) Как скачать форкнутый репозиторий на локальный компьютер?
# Ответ:
# Перейдите на страницу вашего форка на GitHub/GitLab (в вашем аккаунте).
# Нажмите кнопку Code (обычно зеленая).
# Скопируйте URL репозитория (HTTPS или SSH, в зависимости от вашей настройки).
# Откройте кошку.
# Укажите папку куда сохранить
# Нажать кнопку принять
# 33) С какой вероятностью ваши ошибки были уже решены? и кто их решил?
# Ответ:
# С 90% вероятностью задачу и проблему уже решили просто нужно найти в чате Help me
# 34) Как создать файл в vs code?
# Ответ:
# Выберите в меню: File -> New File (Файл -> Новый файл).
#
# VS Code создаст пустую вкладку Untitled-1.
#
# Нажмите Ctrl+S (Cmd+S на Mac) или выберите File -> Save.
#
# Выберите папку для сохранения, введите имя файла с расширением.
#
# Нажмите Save.
# 35) Файл лога нужно заполнять в конце каждого урока?
# Ответ: Да
# ==================
#
# Дополнительные вопросы:
# 1)Какая команда конвертирует файл в py из ipynb?
# подсказка https://t.me/c/1937296927/1/26527
# 2) Что такое пакетный менеджер? Вы пользуетесь пакетным менеджером conda или pip? Какой лучше использовать для дата сайнс?
# 3) Почему расширение py лучше чем ipynb?
# 4) Что такое pep8?
# подсказка:https://peps.python.org/pep-0008/
# 4.1) линтеры проверяют на соблюдение pep8?
# 4.2) Какая нотация используется для создания переменных?
# ответ на 85-95 страницы https://t.me/c/1937296927/1/16676
# 4.3) Может ли переменная состоять из одной буквы например андерскор  "_" ?
# 4.4) Зачем и где мы используем андерскор _
# 4.5) По PEP8 допустима переменная в одну букву?
# ответ на 85-95 страницы https://t.me/c/1937296927/1/16676

# %% [markdown]
# """quiz2"""
#
#
# Список вопросов к видео https://youtu.be/Si9MfV8uJ-0?si=JXHe-tsgOEwSTI5E (НАСТРОЙКА VSCODE, перенос строк, линтеры, работа с ячейками):
#
# (По желанию)В ответе подробно всё опишите и обязательно нужно указывать тайм код из видео где я это сказал, по желанию, дополнительно прикладываем скриншот из видео.
# Если вы знаете ответы на вопросы из Вашего опыта, то таймкоды из видео не надо указывать и т.д.
#
# 1. Как включить автосохранение данных в VSCODE?
# Ответ: file->Auto save
# 2. Как настроить перенос строки?
# Ответ: file->preferences->settings->wrap->ставим значение wrap-далее проставляем значение 79-> сохраняем
# 3. Сколько символов по pep8 разрешено на строке?
# Ответ: 79
# 4. Какие способы переноса строк показаны в видео:
# Ответ: 1)Разделить на новые переменные
#         2) Записать в список и в нем сделать перенос на новую строку
#
# 4.1 Строки с использованием обратного слэша (\)
#
# string_continued = "This is a long string that we want to " \
#                    "split across multiple lines."
# print(string_continued)
#
# 4.2 Тройные кавычки (''' или """)
#
# multi_line_string = """This is a string that spans
# multiple lines. You can write freely
# and it will keep the line breaks."""
# print(multi_line_string)
#
# 4.3 Создание списка строк и объединение с помощью join
#
# strings = [
#     "This is the first line.",
#     "This is the second line.",
#     "This is the third line."
# ]
# result = "\n".join(strings)  # Используем перенос строк '\n'
# print(result)
#
# 4.4 Использование круглых скобок для продолжения строки
# long_string = (
#     "This is a very long string that I would like to "
#     "continue on the next line."
# )
# print(long_string)
#
# 4.5 Форматированные строки (f-строки) с использованием скобок
# letter_a = 5
# letter_b = 6
# product_ab = letter_a * letter_b
#
# message = (
#     f"when {letter_a} is multiplied by {letter_b}, "
#     f"the result is {product_ab}"
# )
# print(message)
#
# 4.6 Сложение строк с помощью +
#
# string_part1 = "This is the first part, "
# string_part2 = "and this is the second part."
# full_string = string_part1 + string_part2
# print(full_string)
#
# 5. Проверка на ошибки c помощью кнопки problems, где она находится?
# ответ: В левом углу сайд бара
# 6. Где в vscode находится клиент гита? как в нём отправить коммит? как принять домашку?
# Ответ: Боковая панель слева значек типа поделиться как на телефоне,Необходимо выбрать файлы добавить их в блок комита, нажать кнопку комит или выбрать из 3 точек как сохранить комит.
# 7. Что такое GIT? он локальный? В нём можно посмотреть историю изменений файлов и вернуться к любому коммиту?
# Ответ: контроль версий.
# Да
# Да
# 8. Как вставить картинку в маркдаун?
# Ответ: ctrl+с и ctrl+v
# Еще можно полность прописать путь до фотки используя тегги языка
# 9. Где посмотреть длину строки в vs code?
# Ответ: создать файл с расширением py, скопировать туда строку кода и в нижней правой части увидеть сколько там символов.
# Так же можно написать цикл который пройдет по строке и сам посчитает сколько там символов.
# 10. Как поменять тип ячейки с питона на маркдаун?
# Ответ: Выделить ячейку(активировать ее) в нижней правой части можно внести изменения
# 11. Как запустить сразу все ячейки в юпитере?
# Ответ: нажать кнопку Run all или Run all cells
# 12. Как изменить размер картинки в юпитере? Нужно для этого знать HTML?
# Ответ: п.8, да
# 13. Какой хоткей чтобы запустить ячейку с смещением на следующую?
# Ответ: shift+enter
# 14. Как включить отображение номеров строк в юпитере(Cell line numbers)?
# Ответ: Правый верхний угол, три точки, show dell number или кнопка L
# 15. Что такое "Go To" чем это полезно? Как перейти сразу на ошибочную ячейку?
# Ответ: Сообщает что в какой то ячейки есть ошибка. Нажать на кнопку GO TO
# 16. Как очистить вывод ячеек которые уже запущены?
# Ответ: Выбрать ячейку нажать кнопку clear all outputs
# 17. Как работать одновременно в нескольких файлах в VSCODE? Что такое SPLIT?
# Ответ: В верхнем правом углу нажать кнопку split.
# 18. Каким сочетанием убирается левый сайдбар?
# Ответ ctrl + b
# 19. Кнопка два листочка это наши локальные файлы?
# Ответ: да
# 20. Какая ошибка появилась в трассировке при запуске всех ячеек DICT или LIST?
# Ответ: Переменной dict не существует
# 21. Вы ознакомились с https://t.me/c/1937296927/832/19307? и https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet?
# Ответ: Да
# 22. Что такое валидация?
# Ответ: это процесс проверки данных на соответствие заданным критериям, стандартам или требованиям.
# 23. Что такое трассировка ошибки?
# Ответ: это отчет, который показывает цепочку вызовов функций/методов, приведших к ошибке.
# 24. Что значит отвалился интерпритатор?
# Ответ: Аварийное завершение работы интерпритатора без возможности восстановления
