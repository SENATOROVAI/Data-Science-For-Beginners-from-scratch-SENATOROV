# %%
"""OSS Quiz."""

# %% [markdown]
# # GitHub
#
# 1.1. Что такое GitHub?
# - веб-платформа для хранения Git-репозиториев и совместной разработки ПО. Она представляет инструменты для работы с кодом, Issues, PR, GitHub Actions, Projects, GH Docs
# 1.2. Как GitHub связан с Git?
# - системой контроля версий, при помощи команд git можно управлять удаленными репозиториями в GH: получать изменения из удаленного репо и отправлять в него локальные коммиты.
# 1.3. Чем отличается fork репозитория от его клонирования (clone)?
# - fork - копия чужого репо, созданная УЗ пользователя GH и сохраняющая связь с исходным репо. Clone - создание локальной копии любого удаленного репо на компьютере разработчика.
# 1.4. Зачем нужны и как работают pull requests?
# - PR - это запрос на включение изменений их одной ветки в другую. Он используется для проверки кода, обсуждения изменений и их слияния с основной веткой проекта. Разраб создает отдельную ветку на GH и создаем PR. Владелец или участники проекта могут проверить код, оставитьт комментарии, запросить доработку, принять изменения или закрыть PR без слияния.
#
# 1.5. GitHub использует ваш почтовый адрес для привязки ваших Git коммитов к вашей учётной записи?
# - Да. GitHub связывает Git-коммит с учётной записью, если адрес электронной почты, указанный в коммите, добавлен и подтверждён в этой учётной записи. Также можно использовать специальный GitHub-адрес вида noreply.
#
# 1.6 Какая команда генерирует SSH ключ для Доступа по SSH к репозиторию (Рисунок 83)
# ssh-keygen -t ed25519 -C "email@example.com"

# %% [markdown]
# # Внесение собственного вклада в проекты
#
# 2. Создайте ишьюс и запомните его номер, в https://github.com/SENATOROVAI/Data-Science-For-Beginners-from-scratch-SENATOROV/issues, назовите его "UPDATE README", в дескрипшене добавьте список задач (Рисунок 102)
# [UPDATE README] #675
#
# 2.1. Если вы хотите вносить свой вклад в уже существующие проекты, в которых у нас нет прав на внесения изменений путём отправки (push) изменений, вы можете создать своё собственное ответвление, что нужно сделать чтобы создать собственное ответвление? (Рисунок 88), сделайте ответвление https://github.com/SENATOROVAI/Data-Science-For-Beginners-from-scratch-SENATOROV, и вставьте сюда ссылку на ваше ответвление
# https://github.com/AmadeyM111/SenatorovAI
#
# 2.2 создайте ветку dev в ФОРКЕ Data-Science-For-Beginners, вставьте сюда ссылку на вашу ветку dev
# https://github.com/AmadeyM111/SenatorovAI/tree/dev
#
# 2.3 В README файле вашего ФОРКА, добавьте ссылку на мой телеграм канал https://t.me/RuslanSenatorov, сохраните коммит, название коммита - в тайтле название ишьюса (#номер_ишьюс), в дескрипшене - Closes #NUMBER-ISSUES номер возьмите из пункта 2
#
#
# 2.4 Отправьте пул реквест из ФОРКА в основу В ВАШУ ВЕТКУ, тайтл пул реквеста скопируйте из ISSUES-TITLE, в дескрипшине пул реквеста напишите Closes #NUMBER-ISSUES вставьте номер из пункта 2
#
# 2.5 Прокомментириуйте ваш пул реквест перед слиянием, перейдите во вкладку(Рисунок 92) и напишите "ок", потом нажимайте сабмит ревью затем не выходя из этой вкладки, в файле README , добавьте туда ссылку на https://t.me/SENATOROVAI
# => инструкция
#
# 2.6 Выполните Merge pull request (Рисунок 116), вставьте сюда ссылку на ваш пул реквест
# https://github.com/SENATOROVAI/Data-Science-For-Beginners-from-scratch-course/pull/676
#
# 2.7 Вставьте сюда ссылку на закрытые пул реквесты в репозитории, найти можно тут
# https://github.com/SENATOROVAI/Data-Science-For-Beginners-from-scratch-course/pulls?q=is%3Apr+is%3Aclosed
#
# 2.8 Как посмотреть какие файлы были в репозитории на момент определенного коммита? вставьте сюда ссылку на любой коммит, где взять ссылку? подсказка:
# Выбираем любой коммит в ВАШЕЙ ВЕТКЕ
# Нажимаем на Browse
# Убедитесь что слева у вас написан номер коммита, потом смотрим какие файлы были в репозитории, на момент этого коммита, это очень полезно если вы накосячили, и хотите откатиться к этому коммиту.
# Поэтому крайне важно называть коммиты ПРАВИЛЬНО, и в коммите должны быть только те файлы которые соответствуют названию коммита, лишних файлов НЕ ДОЛЖНО БЫТЬ, в одном коммите отправлять НЕСКОЛЬКО файлов не надо!
# Как должна выглядеть ссылка
#
# 1f046e29bb683bb6cee36ced92129e2722efc050
#
# 2.9 как открыть запрос слияния, указывающий на другой запрос слияния и зачем это нужно? (Рисунок 117)

# %% [markdown]
# # Рабочий процесс с использованием GitHub
#
# 3. 8 этапов внесения вклада в чужой проект
# - сделать форк исходного репо в свой аккаун гита
# - клонировать свой форк на локальный компьютер
# - создать новую ветку для внесения изменений (git switch -c <branch-ame>)
# - внести изменения в код и проверить их
# - сделать коммит с понятным названием и описанием доработок
# - отправить ветку в свой репо на GH
# - создать PR из своей ветки в ветку исходного репо, добавив заголовки и описание, проставив чек-боксы в шаблоне
# - доработать изменения по замечаниям ревьюеров при их наличии до принятия и слияния PR
#
# 3.1
#
# Какие практики принято соблюдать при создании Pull Request чтобы закрыть автоматический issues?
# - в заголовке PR кратко описать изменение и при необходимости указать номер issue, в описании PR использовать ключ автозакрытия: Closes, Fixes, Resolves
#
# Какие практики принято соблюдать при создании commit чтобы закрыть автоматический issues?
# - в сообщении коммита кратко описать изменение и указать ключ слово с номером issue Fixes #, Issue автоматичемски закроется, когда коммит попадет в основную ветку репо.
#
# 3.2 Как отклонить/закрыть пул реквест? (предоставьте скриншот где это в гитхабе)
#     Откройте репозиторий.
#     Перейдите на вкладку Pull requests.
#     Откройте нужный Pull Request.
#     Прокрутите страницу вниз.
#     Под блоком комментариев нажмите кнопку Close pull request.
#     При желании оставьте комментарий с причиной закрытия.
#     После закрытия при необходимости можно нажать Delete branch, чтобы удалить ветку.
#
# https://docs.github.com/en/pull-requests/how-tos/merge-and-close-pull-requests/closing-a-pull-request?utm_source=chatgpt.com
#
# 3.3 Перед отправкой пул реквеста нужно ли создавать ишьюс?
# - Желательно, особенно при исправлении ошибки или добавлении новой фуункциональности для описания проблемы, предложения решения с владельцем проекта, но это необязательно. При создании важно соблюдать правила конкретного репо из CONTRIBUTING.md
#
# 3.4 В какой вкладке можно посмотреть список изменений который был в пул реквесте? (Рисунок 92)
# - Files Changed
#
# 3.5 В какой вкладке находится страница обсуждений пул реквеста? (Рисунок 94)
# - Conversation

# %%
# Создание запроса на слияние
4 Можно ли открыть пул реквест, если вы ничего не вносили в FORK?
- нет. Pull Request можно открыть только при наличии изменений (коммитов) в вашем fork или ветке по сравнению с веткой исходного репозитория. Без изменений создать Pull Request нельзя.

4.1 Что нужно сделать чтобы открыть пул реквест? (Рисунок 90)
①Клонируем нашу копию
②Создаём тематическую ветку
③Вносим свои изменения
④Проверяем изменения
⑤Фиксируем изменения в тематической ветку
⑥Отправляем новую ветку в нашу копию на GitHub
Теперь, если мы зайдём на страничку нашей копии на GitHub, мы увидим, что GitHub заметил наши изменения и предлагает открыть запрос на слияние с помощью большой зелёной кнопки.
Также можно зайти на страницу «Branches», по адресу
https://github.com/<user>/<project>/branches, найти интересующую ветку и открыть запрос оттуда

4.2 Что нужно сделать Если ваш Форк устарел?
- потдянуть актуальные изменения из исходного репо (upstream) и отправить обновленную ветку в свой fork (origin) Sync fork - Update branch

4.3 Что нужно сделать если в пул реквесте имеются конфликты слияния (Рисунок 96)
- Если в PR возникли конфликты слияния, необходимо разрешить  их: обноить свою ветку актуальными изменениями из целевой ветки, вручную устранить конфликты в файлах, проверить рез-т, сделать новый коммит и отправить изменения git push. После этого PR обновится автоматически.

# %% [markdown]
# # Отрывки кода
#
# 5 Что нужно сделать Для добавления отрывка кода в комментарии к ишьюсу? (Рисунок 104)
# - обрамить его в бэстики ``` ```;
#
# 5.1 На какую клавишу нажать клавишу чтобы выделенный текст был включён как цитата в ваш комментарий?(Рисунок 105)
#  - ``` > ```
#
# 5.2 Как вставить картинку в ишьюс? (Рисунок 108)
# - Перетащить картинку для загрузки и встраивания

# %%
# Поддержание GitHub репозитория в актуальном состоянии

6 Как понять что ваш форк устарел?
- посмотреть последние коммиты upstream, которых нет в нашем fork, сравнив по истории коммитов, либо GitHub покажет сообщение, что fork is behind upstream.

6.1 Как обновить форк?
- получить последние изменения из репо upstream (git fetch upstrea, git merge/git rebase), затем отправить обновленную ветку в свой fork (origin)

# %%
# Добавление участников

7. Как добавить участников в ваш репозиторий, чтобы команда могла работать над одним репозиторием? (Рисунок 112)
- сделать его коллаборантов в настройках git hub - Collaborators

# %% [markdown]
# # Упоминания и уведомления
#
# 8 Какой символ нужен для упоминания кого-либо? (Рисунок 118)
# - @
#
# 8.1 Где находится Центр уведомлений, напишите ссылку (Рисунок 121)
# - https://github.com/notifications?query=

# %%
# Особенные файлы

9 Что такое и зачем нужен файл README
- это лицевая часть проекта с его описанием, зависимостями, требованиям, примеры использования, инструкцией развертывания и запуску, информация о лицензиях и авторах. Он помогает пользователям и разработчикам понять назначение проекта, способы его установки, запуска и использования.

9.1 Что такое и зачем нужен файл CONTRIBUTING (Рисунок 122)
- Если в вашем репозитории будет файл CONTRIBUTING с
любым расширением, то GitHub будет показывать ссылку на него при создании любого
запроса на слияние. 
Вы можете указать конкретные вещи, которые вы хотите или не
хотите видеть в новых запросах на слияние. Таким образом люди могут ознакомится с
руководством, перед тем как создавать новый запрос на слияние.

# %% [markdown]
# # Управление проектом
#
# 10 Как изменить основную ветку (Рисунок 123)
# -  прозвести изменения в настройках репозитрия на закладке "Options". Выбрать нужную ветку из выпадающего меню и она станет основной для большнства операций, включая изменение кода при клонировании репо.
#
# 10. 1 Как передать проект? какая кнопка? (рисунок 124)
# - нажать «Transfer ownership» в настройках репозитория на
# закладке «Options».
#
# 10.2 Что такое файл .gitignore?
# - файл, который содержит список файлов и каталогов, которые Git должен игнорировать и не добавлять в репо, такие как .venv, .env, docs, xlsx, датасеты. Он используется, чтобы не хранить временные файлы, зависимости, конфиденциальные и большие данные. Он действует только на неотслеживаемые файлы, которые не попали в индекс.
# .gitignore бывает кастомным и шаблонным под каждый язык программирования
