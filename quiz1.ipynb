# %% [markdown]
# Список вопросов к видео https://t.me/c/1937296927/765/29780 (АЛГОРИТМ ПРИНЯТИЯ И ОТДАЧИ ДОМАШКИ):
#
# (По желанию )В ответе подробно всё опишите и обязательно нужно указывать тайм код из видео где я это сказал, по желанию, дополнительно прикладываем скриншот из видео.
# Если вы знаете ответы на вопросы из Вашего опыта, то таймкоды из видео не надо указывать и т.д.
#
# 1) Как понять, что домашка пришла?
#
# telegram -> чат HomeWork -> придет сообщение (Пример: @EgAvr_sol прими пул) -> далее нужно его принять
#
# 2) Как принять домашку?
#
# Идем в "КОШЕЧКУ" ;) (GitHub Desktop) -> fetch origin -> На вкладке history можно посмотреть что делалось
#
# 3) Зачем нужна кнопка history и какие функции появляются при нажатии правой кнопки мыши на коммит?
#
# Можно увидеть что же произошло с проектом, какие были изменения. При нажатии на правую кнопку можно -> View on GitHub этого коммит-а еще -> copy SHA -> а так-же -> revert changes in commit - это откат к коммиту, аналог этой кнопки в GIT команда `git reset --soft SHA_коммита_(хеш_сумма)`
#
# 3.1) Где брать ссылку на коммит? куда её отправлять?
#
# Делаем Push в наш "форкнутый" репозиторий (удаленный) всех изменений, и затем в нем уже (перейти на удаленный репозиторий (в "кошечке") кнопкой -> View on GitHub) либо просто на [сайте](https://github.com) в нужном проекте, находим наш коммит -> Commits (часики нарисованные) -> переходим в него видим сделанные изменения и можем скопировать ссылку на коммит
#
# 4) Что такое файл лога?
#
# Туда пишем свои пометки по "домашке" или уроку который проходим. Файл (называем например log.ipynb) для каждого дня отдельную ячейку markdown. Пример содержимого:
# 21.05.2025
#
# 1.Выполняю quiz.ipynb
#
# 2.Изучаю git, линтеры, виртуальные окружения.
#
# 4.1) Когда нужно его пушить?
#
# Когда закончили выполнение домашней работы, вместе с файлами урока
#
# 5) Что такое интерпритатор?
#
# Программа которая запускает (интерпретирует) наш код
#
# 6) Где можно выбрать интерпритатор?
#
# Прям в интерфейсе есть выбор интерпретатора, для файлов .ipynb типа (этот тип - это файл в формате json)
#
# 7) Что такое модуль?
#
# Это наши файлы .py файлы .ipynb это файлы интерактивные для анализа и экспериментов с кодом.
#
# 8) Как создать и отправить коммит?
#
# Кнопка -> commit to main предварительно написав описание (локальный коммит) и затем push origin (коммит в удаленный репозиторий)
#
# 9) Как посмотреть что коммит точно отправлен и находится в github?
#
# Найти на сайте, посмотреть в истории commits
#
# 10) Какая команда показывает что код не прошёл проверки на ошибки?
#
# Команда `pre-commit run --all-files`
#
# 10.1) Напишите список линтеров которые используются для проверки кода и дайте их краткую характеристику.
#
# pylint - для поддержки PEP-8 стандарта
#
# black - исправляет, форматирует кода, он может убирать/добавлять лишние/нужные пробелы,отступы
#
# mypy - для проверок на строгую типизацию кода
#
# isort → сортировка импортов.
#
# nbQA - позволяет запускать инструменты, которые обычно работают только с .py файлами, на .ipynb файлах. Он "извлекает" Python-код из ячеек ноутбука, применяет линтер или форматер, а затем возвращает исправленный код обратно
#
# 11) Как узнать какой именно линтер не прошёл проверку?
#
# После команды `pre-commit run --all-files` увидим в консоли выделенные ошибки, и статус выполнения каждого линтера.
#
# 12) Линтер Pylint видит markdown?
#
# Нет, он его пропускает
#
# 13) Номер ячейки в терминале и номер ячейки в vs code может отличаться? в каком случае?
#
# Так как линтер пропускает ячейки с markdown, в выводе линтера могут быть указаны другие номера ячеек, не те которые по факту в vs code.
#
# 14) Где посмотреть номер ячейки в vscode?
#
# с левой стороны от ячейки
#
# 15) В каком формате ipynb отправляется в гитхаб? причём здесь JSON?
#
# JSON это формат файлов в котором и хранятся файлы расширения .ipynb
#
# 16) Где посмотреть в какой ячейке ошибка?
#
# В низу от названия линтера. -> C правой стороны от названия файла номер ячейки
#
# 17) Как запустить терминал?
#
# Комбинация <win> + r и потом-> cmd
# или прям в IDE вкладка terminal
#
# 18) Что такое линтер?
#
# Это модули языка python которые проверяют код на соответствие PEP 8,
# на соответствие типов PEP 484,
# на соответствие стилю кодирования,
# кроме того, умеют исправлять некоторые "косяки", форматируют код (может убирать/добавлять лишние/нужные пробелы, отступы)
#
# 19) В какой сайт нужно вставлять код ошибки если ошибка связана с pylint?
#
# [link](https://pylint.readthedocs.io/en/stable/tutorial.html)
#
# 20) Секция pydocstyle в большинстве случае автоматический закрывается после исправления ошибок в каком линтере?
#
# Линтер pylint
#
# 21) Что такое описание модуля? Оно должно отражать информацию о том что находится в модуле?
#
# Да должно кратко и емко описывать что делаем модуль, как работает, как им пользоваться.
#
# 21) С какой  git команды начинается утро программиста?
#
# `git pull` - посмотреть не сделал ли кто изменения в репозиторий
#
# 22) После внесения изменений в файлах, кнопка open in vs code пропадает в кошке, как по другому открыть vs code из кошки?
#
# Зато появится: Current repository (текущий репозиторий) -> Open in VS Code
#
# 23) Что такое stash?
#   Общее объяснение концепции.
#
# При операции pull, могут возникнуть конфликтные ситуации, когда программы автоматически не может принять pull из удаленного репозитория, то есть те изменения которые у нас в локальном репозитории, конфликтуют с изменениями которые содержаться в удаленном репозитории. У нас в GitHub desktop произойдет ошибка Error
# и появится кнопка -> Stash Changes and Continue Это нам говорит что git hub не знает какое из изменений оставить, которое у нас в локальном репозитории, или то которое в удаленном репозитории. И он предлагает спрятать наши локальные изменения в буфер обмена, а принять изменения из удаленного репозитория.
#
# 23.1) Как сохранить стэш?
#   git командa(подсказка: https://t.me/c/1937296927/3602/19531):
#
#   Кнопка в vs code:
#
# ![button_Stash](img/stash.png)
#
# 23.2) Как восстановить стэш(подсказка: https://t.me/c/1937296927/3602/25747)?:
#
#       git команда(подсказка: https://t.me/c/1937296927/3602/19531)?:
#
# `git stash apply "NUMBER_STASH"`
#
# 23.3) Различие между стэшем и коммитом.
#   Когда лучше сохранить изменения в стэше, а когда коммитить.
#
# Stash делают если в локальном репозитории есть конфликт с удаленным репозиторием. А коммит это сохранение в локальном репозитории наших изменений с определенным комментарием для последующего push в удаленный репозиторий.
#
# 23.4) Как просмотреть список сохраненных стэшей?
#   git команда (подсказка: https://t.me/c/1937296927/3602/19531):
#
# `git stash list`
#
# 23.5) Как удалить стэш?
#   Команды для удаления отдельных стэшей или всех сразу.
#   git команда (подсказка: https://t.me/c/1937296927/3602/19531):
#
# `git stash drop stash@{n}`
# `git stash clear`
#
# 23.6) Практические примеры использования стэша.
#   Краткие сценарии, где стэш помогает.
#
# При возникновении конфликта нашего локального репозитирия и изменениями которые приходят из удаленного репозитория.
#
# 24) Где посмотреть что есть конфликт в файлах?
#
# Есть команда `git log --merge`
# Либо в "кошечке" будет произойдет ошибка Error
# и появится кнопка -> Stash Changes and Continue
#
# 24.1) Когда он появляется?
#
# При конфликте локальных изменений с теми которые приходят из удаленного репозитория (при git pull)
#
# 25) Как решить конфликт в файлах?
#
# нам можно:
# -> Accept Current Change (принять текущие изменения одного цвета) (пришли с github)
# -> Accept Incoming Change (принять входящие изменения другого цвета) (наши локальные)
# -> Accept Both Changes (принять оба изменения обоих цветов)
# -> Compare Changes (сравнить изменения)
# После выбора нужного варианта мы можем нажать -> Resolve in Merge Editor и затем убедившись в правильности или отредактировав нажать -> Complete Merge
#
# 26) Напишиие правильное утверждение
# -Зелёное то что пришло с гитхаба и синее локальные изменения или синее то что пришло с гитхаба и зелёное это локальные изменения
#
# Ответ: Зелёное то что пришло с GitHub (удаленного репозитория) а синее наши локальные изменения
#
# 27) Если мы работаем в одном файле, можно ли принять pull после того как вы спрячете в стэш свои изменения?
#
# Можно, при stash команде система git просто спрячет наши изменения, и можно принять pull.
#
# 27.1) Что может произойти когда stash восстановите после принятия pull?
#
# Конфликт наших лок. изм. и изменений приходящих из удален. реп.
#
# 28) Сколько способов решения конфликтов было показано в видео? Напишите ЧИСЛО и укажите их способы.
#
# 2-а способа. В спец программах как GitHub Desktop, или в ручную (через терминал, используя редактор кода)
#
# 29) Что делает кнопка complete merge?
#
# Применяет сделанные изменения (говорит системе git "конфликты мы разрешили, сохраняй в таком виде")
#
# 30) В какой чат нужно писать если остались вопросы?
#
# Telegram - HELP ME
#
# 31) Что такое FORK? Зачем его делают?
#
# Это наш способ скопировать себе чей то репозиторий и взаимодействовать с оригинальным репозиторием через pull requests.
#
# 32) Как скачать форкнутый репозиторий на локальный компьютер?
#
# `git clone <link>`
# Или в "кошечке" File -> clone repository
#
# 33) С какой вероятностью ваши ошибки были уже решены? и кто их решил?
#
# Около 99.9% всегда можно спросить у google :) Или в чате HELP ME.
#
# 34) Как создать файл в vs code?
#
# Кнопка -> New file
#
# 35) Файл лога нужно заполнять в конце каждого урока?
#
# Да в конце каждого урока, с кратким описанием что делали.
#
# ==================
#
# Дополнительные вопросы:
# 1)Какая команда конвертирует файл в py из ipynb?
# подсказка https://t.me/c/1937296927/1/26527
#
# Если установлен Jupyter, просто запуском команды в терминале:
# `jupyter nbconvert --to python <наш_файл>.ipynb`
# будет сохранен файл <наш_файл>.py
#
# Можно просто открыть файл в Jupyter Notebook, перейти в File → Download as → Python (.py).
#
# 2) Что такое пакетный менеджер? Вы пользуетесь пакетным менеджером conda или pip?Какой лучше использовать для дата сайнс?
#
# Есть менеджеры пакетов pip, poetry.
# Для Data science используется Conda
#
# 3) Почему расширение py лучше чем ipynb?
#
# .py более универсальное расширение, такой код запустится единообразно в одной последовательности, и для работы нет надобности в Jupyter.
#
# 4) Что такое pep8?
# подсказка:https://peps.python.org/pep-0008/
#
# Правила стиля оформления кода.
#
# 4.1) линтеры проверяют на соблюдение pep8?
#
# Да конечно ;)
#
# 4.2) Какая нотация используется для создания переменных?
# ответ на 85-95 страницы https://t.me/c/1937296927/1/16676
#
# Так называемая нотация snake_case
# (например, my_variable, calculate_average)
# Допустим еще camelCase
# (например, myVariable, CalculateAverage)
#
# Но для Python snake_case более предпочтительна
#
# 4.3) Может ли переменная состоять из одной буквы например андерскор  "_" ?
#
# Да может, если она нужна только для отработки кода. А сама переменная не будет использоваться, но принять ее мы обязаны.
#
# 4.4) Зачем и где мы используем андерскор _
#
# Для разделения слов в именах переменных или функций на примере snake_case
# Или даже просто как один символ будет переменная которая не будет дальше в коде использоваться
# Или используется в магических методах __Init__ или protected / private переменных или методов (например: _name / __name)
#
# 4.5) По PEP8 допустима переменная в одну букву?
# ответ на 85-95 страницы https://t.me/c/1937296927/1/16676
#
# Да допустима
