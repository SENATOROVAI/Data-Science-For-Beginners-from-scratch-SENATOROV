# %%
"""Date and time."""

# %%
import datetime
from datetime import datetime, timedelta

import pandas as pd
import pytz

# %%
print(datetime.datetime.now())
# Out:
# 2026-07-31 17:25:40.809613

# %%
print(datetime.now())
# Out:
# 2026-07-31 17:26:23.484882

# %%
cur_dt = datetime.now()
print(cur_dt)
# Out:
# 2026-07-31 17:27:40.920614

# %%
print(
    cur_dt.year,
    cur_dt.month,
    cur_dt.day,
    cur_dt.hour,
    cur_dt.minute,
    cur_dt.second,
    cur_dt.microsecond,
)
# Out:
# 2026 7 31 17 27 40 920614

# %%
print(cur_dt.weekday(), cur_dt.isoweekday())
# Out:
# 4 5

# %%
print(cur_dt.tzinfo)
# Out:
# None

# %%
dt_moscow = datetime.now(pytz.timezone("Europe/Moscow"))
print(dt_moscow)
# Out:
# 2026-07-31 17:55:02.061898+03:00

# %%
print(dt_moscow.tzinfo)
# Out:
# Europe/Moscow

# %%
timestamp = datetime.now().timestamp()
print(timestamp)
# Out:
# 1785509812.59897

# %%
print(datetime.fromtimestamp(timestamp))
# Out:
# 2026-07-31 17:56:52.598970

# %%
hb = datetime(1991, 2, 20)
print(hb)
# Out:
# 1991-02-20 00:00:00

# %%
print(hb.year)
# Out:
# 1991

# %%
print(datetime.timestamp(hb))
# Out:
# 666997200.0

# %%
str_to_dt = "2007-12-02 12:30:45"
type(str_to_dt)
# Out:
# str

# %%
res_dt = datetime.strptime(str_to_dt, "%Y-%m-%d %H:%M:%S")

print(res_dt)
print(type(res_dt))
# Out:
# 2007-12-02 12:30:45
# <class 'datetime.datetime'>

# %%
dt_to_str = datetime(2002, 11, 19)
type(dt_to_str)
# Out:
# datetime.datetime

# %%
res_str = datetime.strftime(dt_to_str, "%A, %B %d, %Y")

print(res_str)
print(type(res_str))
# Out:
# Tuesday, November 19, 2002
# <class 'str'>

# %%
date1 = datetime(1905, 6, 30)
date2 = datetime(1916, 5, 11)

# %%
date1 < date2
# Out:
# True

# %%
date1 > date2
# Out:
# False

# %%
"2007-12-02" > "2002-11-19"
# Out:
# True

# %%
datetime(2007, 12, 2) > datetime(2002, 11, 19)
# Out:
# True

# %%
diff = date2 - date1
print(diff)
# Out:
# 3968 days, 0:00:00

# %%
type(diff)
# Out:
# datetime.timedelta

# %%
print(diff.days)
# Out:
# 3968

# %%
timedelta(days=1)
# Out:
# datetime.timedelta(days=1)

# %%
future = datetime(2070, 1, 1)
future
# Out:
# datetime.datetime(2070, 1, 1, 0, 0)

# %%
time_travel = timedelta(days=365) * 170

past = future - time_travel

past
# Out:
# datetime.datetime(1900, 2, 12, 0, 0)

# %%
datetime(2070, 1, 1) - datetime(1900, 1, 1)
# Out:
# datetime.timedelta(days=62092)

# %%
time_travel = timedelta(days=62092)

past = future - time_travel
past
# Out:
# datetime.datetime(1900, 1, 1, 0, 0)

# %%
365 * 170
# Out:
# 62050

# %%
datetime(2070, 1, 1) - datetime(1900, 1, 1)
# Out:
# datetime.timedelta(days=62092)

# %%
cur_date = datetime(2021, 1, 1)
end_date = datetime(2021, 1, 10)

while cur_date <= end_date:

    print(cur_date.strftime("%b %d, %Y"))

    cur_date += timedelta(days=1)
# Out:
# Jan 01, 2021
# Jan 02, 2021
# Jan 03, 2021
# Jan 04, 2021
# Jan 05, 2021
# Jan 06, 2021
# Jan 07, 2021
# Jan 08, 2021
# Jan 09, 2021
# Jan 10, 2021

# %%
numbers = ["5", "10", "a", "15", "10"]

total = 0

for number in numbers:

    try:
        total += int(number)
    except:
        pass

total
# Out:
# 40

# %%
total = 0

for number in numbers:
    try:
        total += int(number)
    except:
        print(f"Элемент '{number}' обработать не удалось")

total
# Out:
# Элемент 'a' обработать не удалось
# 40

# %%
temp = pd.read_csv("temperature.csv")
temp
# Out:
#           Date  Temp
# 0   2002-01-01  47.1
# 1      2002-02  50.5
# 2    2002-03-1  54.9
# 3      2002-04  66.1
# 4   2002-05-01  72.7
# 5      2002-06  83.2
# 6      2002-07  88.8
# 7    2002-08-1  87.8
# 8   2002-09-01  80.2
# 9   2002-10-01  64.1
# 10     11-2002  53.9
# 11  2002-12-01  44.1

# %%
formats = ["%Y-%m-%d", "%Y-%m-%-d", "%Y-%m"]

counter = 0

for d in temp.Date:

    for format in formats:

        try:
            print(datetime.strptime(d, format))
            counter += 1

        except:

            pass


print("Не обработалось записей:", len(temp) - counter)
# Out:
# 2002-01-01 00:00:00
# 2002-02-01 00:00:00
# 2002-03-01 00:00:00
# 2002-04-01 00:00:00
# 2002-05-01 00:00:00
# 2002-06-01 00:00:00
# 2002-07-01 00:00:00
# 2002-08-01 00:00:00
# 2002-09-01 00:00:00
# 2002-10-01 00:00:00
# 2002-12-01 00:00:00
# Не обработалось записей: 1

# %%
temp_parsed = pd.read_csv("temperature.csv", index_col="Date", parse_dates=True)
temp_parsed
# Out:
#             Temp
# Date
# 2002-01-01  47.1
# 2002-02     50.5
# 2002-03-1   54.9
# 2002-04     66.1
# 2002-05-01  72.7
# 2002-06     83.2
# 2002-07     88.8
# 2002-08-1   87.8
# 2002-09-01  80.2
# 2002-10-01  64.1
# 11-2002     53.9
# 2002-12-01  44.1

# %%
type(temp_parsed.index)
# Out:
# pandas.Index
