# %%
"""Data types."""

# %%
A1 = 25
B1 = 2.5
C1 = 3 + 25j

# %%
D1 = 2e3
print(D1)
print(type(D1))
# Out:
# 2000.0
# <class 'float'>

# %%
print(2 + 2, 4 - 2, 2 * 2, 4 / 2, 2**3)
# Out:
# 4 2 4 2.0 8

# %%
print(7 // 2)
print(7 % 2)
# Out:
# 3
# 1

# %%
FIRST_NUMBER = 2
SECOND_NUMBER = 4
THIRD_NUMBER = 3

print(FIRST_NUMBER == SECOND_NUMBER)
print(FIRST_NUMBER != SECOND_NUMBER)
print(SECOND_NUMBER > FIRST_NUMBER and FIRST_NUMBER != THIRD_NUMBER)
# Out:
# False
# True
# True

# %%
print(4 > 2 and 2 != 3)
print(4 < 2 or 2 == 2)
print(not (4 == 4))
# Out:
# True
# True
# False

# %%
D2 = 25

BIN_D = bin(D2)
print(BIN_D)

print(int(BIN_D, 2))
# Out:
# 0b11001
# 25

# %%
STRING_1 = "строка"
STRING_2 = "строка"

# %%
MYLTI_STRING = """ArithmeticError,
пцолпоцп,
абецп."""

# %%
len(MYLTI_STRING)
# Out:
# 33

# %%
A2, B2, C2 = "Программирование", "на", "Python"
A2 + " " + B2 + " " + C2
# Out:
# 'Программирование на Python'

# %%
print(MYLTI_STRING[0])
print(MYLTI_STRING[-1])
# Out:
# A
# .

# %%
print(MYLTI_STRING[3:10])
# Out:
# thmetic

# %%
print(MYLTI_STRING[:2])
print(MYLTI_STRING[3:])
# Out:
# Ar
# thmeticError,
# пцолпоцп,
# абецп.

# %%
for i in "питон":
    print(i)
# Out:
# п
# и
# т
# о
# н

# %%
print("***15 849 302***".strip("*"))
print(" 15 849 302 ".strip())
# Out:
# 15 849 302
# 15 849 302

# %%
print(MYLTI_STRING.split())
# Out:
# ['ArithmeticError,', 'пцолпоцп,', 'абецп.']

# %%
len(MYLTI_STRING.split())
# Out:
# 3

# %%
DATA = "20,25"

DATA = DATA.replace(",", ".")

DATA = float(DATA)
print(DATA)
print(type(DATA))
# Out:
# 20.25
# <class 'float'>

# %%
VAR = True
type(VAR)
# Out:
# bool

# %%
if VAR == True:
    print("Переменная VAR имеет значение True")
else:
    print("Переменная VAR имеет значение False")
# Out:
# Переменная VAR имеет значение True

# %%
list_1 = [1, 2, 3, 4, 5]
str(list_1)
# Out:
# '[1, 2, 3, 4, 5]'

# %%
list_str = []
for X5 in list_1:
    list_str.append(str(X5))

print(list_str)
# Out:
# ['1', '2', '3', '4', '5']

# %%
[str(X6) for X6 in list_1]
# Out:
# ['1', '2', '3', '4', '5']

# %%
list(map(str, list_1))
# Out:
# ['1', '2', '3', '4', '5']
