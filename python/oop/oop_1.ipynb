# %%
"""Objects and classes."""
# Out:
# 'Objects and classes.'

# %%
class Person:
    name = "Ivan"

# %%
Person.name
# Out:
# 'Ivan'

# %%
Person.__name__
# Out:
# 'Person'

# %%
dir(Person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'name']

# %%
Person.__class__
# Out:
# type

# %%
p = Person()

# %%
p.__class__
# Out:
# __main__.Person

# %%
p.__class__.__name__
# Out:
# 'Person'

# %%
type(p)
# Out:
# __main__.Person

# %%
new_person = type(p)()

# %%
new_person

# %%
id(p)
# Out:
# 131819130633296

# %%
id(new_person)
# Out:
# 131819130758416
