# %%
"""Methods."""
# Out:
# 'Methods.'

# %%
class Person:
    name = "Ivan"


print(Person.__dict__)
# Out:
# {'__module__': '__main__', 'name': 'Ivan', '__dict__': <attribute '__dict__' of 'Person' objects>, '__weakref__': <attribute '__weakref__' of 'Person' objects>, '__doc__': None}

# %%
p1 = Person()

# %%
p1

# %%
p2 = Person()

# %%
id(p1)
# Out:
# 135048339038976

# %%
id(p2)
# Out:
# 135048338895120

# %%
p1.name
# Out:
# 'Ivan'

# %%
p2.name
# Out:
# 'Ivan'

# %%
id(p1.name)
# Out:
# 135048339036304

# %%
id(p2.name)
# Out:
# 135048339036304

# %%
p1.__dict__
# Out:
# {}

# %%
p2.__dict__
# Out:
# {}

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'name': 'Ivan',
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None})

# %%
p1.name = "Oleg"

# %%
p2.name = "Dima"

# %%
p1.__dict__
# Out:
# {'name': 'Oleg'}

# %%
p2.__dict__
# Out:
# {'name': 'Dima'}

# %%
p2.age = 123

# %%
p2.__dict__
# Out:
# {'name': 'Dima', 'age': 123}

# %%
p1.name
# Out:
# 'Oleg'

# %%
p2.name
# Out:
# 'Dima'

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'name': 'Ivan',
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None})

# %%
p1.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 p1.age
#
# AttributeError: 'Person' object has no attribute 'age'

# %%
p1 = Person()

# %%
p2 = Person()

# %%
Person.name = "eifqwefiqw"

# %%
p1.name
# Out:
# 'eifqwefiqw'

# %%
p2.name
# Out:
# 'eifqwefiqw'
