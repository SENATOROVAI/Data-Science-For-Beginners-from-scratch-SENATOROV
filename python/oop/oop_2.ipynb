# %%
"""Atributes and funtions."""
# Out:
# 'Atributes and funtions.'

# %%
class Person:
    name = "Ivan"

# %%
dir(Person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'name']

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'name': 'Ivan',
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None})

# %%
Person.__dict__["name"] = "afaefa"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Person.__dict__['name']='afaefa'
#
# TypeError: 'mappingproxy' object does not support item assignment

# %%
Person.name
# Out:
# 'Ivan'

# %%
Person.age = 234324

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'name': 'Ivan',
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None,
#               'age': 234324})

# %%
getattr(Person, "name")
# Out:
# 'Ivan'

# %%
setattr(Person, "dob", "123")

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'name': 'Ivan',
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None,
#               'age': 234324,
#               'dob': '123'})

# %%
delattr(Person, "dob")

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'name': 'Ivan',
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None,
#               'age': 234324})

# %%
class Person:
    name = "Ivan"

    def hello():
        print("Hello")


# Person.hello()
print(Person.__dict__)
# Out:
# {'__module__': '__main__', 'name': 'Ivan', 'hello': <function Person.hello at 0x7c72a42191c0>, '__dict__': <attribute '__dict__' of 'Person' objects>, '__weakref__': <attribute '__weakref__' of 'Person' objects>, '__doc__': None}
