# %%
"""Classes functions."""
# Out:
# 'Classes functions.'

# %%
class Person:
    def hello():
        print("Hello")

# %%
Person.hello
# Out:
# <function __main__.Person.hello()>

# %%
p = Person()

# %%
p.hello
# Out:
# <bound method Person.hello of <__main__.Person object at 0x710ef25604d0>>

# %%
hex(id(p))
# Out:
# '0x710ef25604d0'

# %%
Person.hello()
# Out:
# Hello

# %%
p.hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 p.hello()
#
# TypeError: Person.hello() takes 0 positional arguments but 1 was given

# %%
type(p.hello)
# Out:
# method

# %%
type(Person.hello)
# Out:
# function

# %%
id(Person.hello)
# Out:
# 124309009353440

# %%
id(p.hello)
# Out:
# 124309009605312

# %%
dir(Person.hello)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__']

# %%
dir(p.hello)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__func__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
p.__dict__
# Out:
# {}

# %%
"person-dima".split("-")
# Out:
# ['person', 'dima']

# %%
"person".split("-")
# Out:
# ['person']

# %%
Person.hello()
# Out:
# Hello

# %%
Python.hello(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Python.hello(p)
#
# NameError: name 'Python' is not defined

# %%
Person.hello(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 Person.hello(p)
#
# TypeError: Person.hello() takes 0 positional arguments but 1 was given

# %%
p.hello.__self__

# %%
hex(id(p))
# Out:
# '0x710ef25604d0'

# %%
p.hello.__func__
# Out:
# <function __main__.Person.hello()>

# %%
p.hello.__func__(hello.__self__, *args)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 p.hello.__func__(hello.__self__, *args)
#
# NameError: name 'hello' is not defined

# %%
class Person:
    def hello(instance):
        print(instance)

# %%
p = Person()

# %%
p.hello()

# %%
hex(id(p))
# Out:
# '0x710ef2561550'

# %%
class Person:
    def hello(self):
        print(self)
