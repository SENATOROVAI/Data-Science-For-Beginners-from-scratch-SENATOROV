# %%
"""init."""
# Out:
# 'init.'

# %%
class Person:
    pass

# %%
p = Person()

# %%
p.name = "Ivan"

# %%
p.name
# Out:
# 'Ivan'

# %%
class Person:
    def __init__(self, name):
        self.name = "Ivan"

    def display(self):
        print(self.name)

# %%
p = Person()

# %%
p.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 p.display()
#
# Cell In[7], line 6, in Person.display(self)
#       5     def display(self):
# ----> 6         print(self.name)
#
# AttributeError: 'Person' object has no attribute 'name'

# %%
p.__dict__
# Out:
# {}

# %%
p.create()

# %%
p.__dict__
# Out:
# {'name': 'Ivan'}

# %%
p = Person("ivan")

# %%
p.name
# Out:
# 'Ivan'

# %%
p.__dict__
# Out:
# {'name': 'Ivan'}

# %%
p.age = 123
