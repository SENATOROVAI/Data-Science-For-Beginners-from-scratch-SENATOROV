# %%
"""Introduced in Python."""

# %% [markdown]
# 1. Что такое CPython и чем он отличается от Python?
# - CPython - это наиболее распространенная реализация Python с компилятором, написанная на С и компилируется С-компилятором.
# - CPython используется для выполнения большинства Python-программ.
# - Это не ЯП это реализация Python на языке программирования C.
# - Реализация исполняет байт-код, созданный интерпретатором.
# - Python описывет синтаксис, а CPython интерпретирует их.
#
# 2. Официально порядка 9, но в лекции упоминается 6.
#
# 4. На С.
#
# 5. Guido van Rossum
#
# 6. Python считается языком с высокой скоростью разработки, он уступает по скорости исполнения с С или Rust, но многие тяжелые вычисления выполняются не на Python, а на высокопроизводительных библиотеках, написанных на С и С++ или Fortran.
#
# Он быстр за счет компиляции в байт-код, а не разбирается построчно, а также имеет быстрый интерпретатор CPython и оптимизированные библиотеки NumPy6, Pandas, OpenCV, TensorFlow выполняет тяжелые операции на С/C++ которая выполняется на CPU.
#
# Но Python медленнее С, поскольку каждая операция работает с полноценным объектом, а не байт-кодом, но для реализации ПО требуется меньше кода.
#
# 7. (base) amadey@MacBook-Pro python % python3 -c "import sys; print(sys.executable)"
# /opt/homebrew/Caskroom/miniconda/base/bin/python3
#
# 8. Что содержится в папке include в CPython?
# - заголовочне файлы С (.h), которые объявляют структуры, функции, макросы, константы - это и есть интерфейс (API) CPython
#
# 9. Где можно найти исходный код CPython дайте ссылку на репозиторий гитхаб
# - https://github.com/python/cpython/tree/main/Include
#
# 10. (опционально) Как работает интерпретатор CPython при выполнении кода?
# Подготовительный этап(один раз):
# 10.1. Исходный код СPython, написанный на С, компилируется компилятором (Clang) и линкуется в исполняемый файл python.
#
# Во время выполнения программы:
# 10.2 Интерпретатор CPython читает исходный .py
# 10.3 Выполняет лексический анализ, синтаксический анализ (парсинг) и строит AST (абстрактное синтаксичекое дерево)
# 10.4 Компилирует AST в байткод Python.
# 10.5 Python Virtual Machine последовательно интерпретирует инструкции байткода.
# 10.6 Для выполнения каждой инструкции используется соответсвующие функции СPython, написанный на языке С, которые взаимодействуют с памятью,ОС и процессором.
#
# Запуск файла с помощью CPython
#
# 11. Какая команда используется для запуска файла с помощью CPython?
# - python script.py | python3 script.py
# 12. Можно ли запускать текстовые файлы через интерпретатор Python? Почему?
# - Да, если их содержимое является корректным python-кодом
# 13. Как указать путь к интерпретатору и файлу для выполнения кода?
# - /opt/homebrew/bin/python3 \ /Users/Username/proj/main.py
#
#
# Введение в PyPy
#
# 14. Чем PyPy отличается от CPython?
# - PyPy гораздо быстрее CPython за счет JIT-компилляции
#
# Почему PyPy не может использоваться для всех проектов на Python?
# - может не работать с библиотеками и расширениями, написаннымит специально на CPython на C.
#
# Где можно скачать PyPy?
# - https://pypy.org/
#
# Установка и запуск PyPy
#
# 17. Как установить PyPy после скачивания?
# запускаем интерпретатор python3.10.exe
#
# 18. Как запустить файл с помощью PyPy?
# - копируем путь интерпретатора в cmd + пробел + путь полный до файла с названием файла
# 19. Почему PyPy выполняет код быстрее, чем CPython?
# - быстрее при запуске чистого кода за счет JIT-компиляции, но некоторые библиотеки и расширения, написанные с использованием CPython С API, могут работать медленнее, быть несовместимыми или требовать спец слоя совместимости (cpyext)

# %% [markdown]
# Практические задания
#
# Задание 1: Поиск и установка CPython
#
# Проверьте, установлен ли CPython на вашем компьютере:
#     Используйте поиск в меню "Пуск" (Windows) или терминале (Linux/Mac).
#     Введите команду python --version или python3 --version в терминале.
#
# - /Users/amadey/opt/homebrew/bin/python
#
# Задание 2: Исследование структуры CPython
#
# Откройте папку include и изучите её содержимое. Какое количество файлов на C там есть?
# - 295
#
# Задание 3: Запуск файла с помощью CPython
#
# Создайте текстовый файл example.txt с содержимым:
# print("Hello from CPython!")
#
# Запустите файл через команду python <путь_до_файла> (замените <путь_до_файла> на фактический путь к вашему файлу).
#
# Проверьте, что выводится на экран. Попробуйте изменить расширение файла на .py и повторите запуск.
# - (base) amadey@MacBook-Pro SenatorovDS % python python/example.txt
# Hello from CPython!
# (base) amadey@MacBook-Pro SenatorovDS % python python/example.py
# Hello from CPython!
#
# Задание 4: Установка и использование PyPy
#
# Перейдите на [официальный сайт PyPy](https://www.pypy.org/) и скачайте подходящую версию для вашей операционной системы.
# Распакуйте скачанный архив в удобное место.
# Создайте файл example_pypy.py с кодом:
# print("Hello from pypy!")
#
# Запустите файл через PyPy
# pypy <путь_до_файла> (замените <путь_до_файла> на фактический путь к вашему файлу).
# Проверьте, что выводится на экран. Попробуйте изменить расширение файла на .py и повторите запуск.
# ```
# (base) amadey@MacBook-Pro SenatorovDS % /Users/amadey/devwork/python/pypy3.11-v7.3.23-macos_arm64/bin/pypy3 python/example_pypy.py
# Hello from pypy!
# ```
#
# Задание 5: Сравнение производительности CPython и PyPy
#
# Создайте файл performance_test.py с кодом:
#     import time
#     start_time = time.time()
#     total = 0
#     for i in range(1, 10000000):
#         total += i
#     end_time = time.time()
#
#     print("Result:", total)
#     print("Execution time:", end_time - start_time, "seconds")
# Запустите этот файл сначала через CPython, а затем через PyPy. Запишите результаты времени выполнения для обоих интерпретаторов.
#
# ```
# (base) amadey@MacBook-Pro SenatorovDS % python3 python/performance_test.py
# Result: 49999995000000
# Execution time: 0.27011775970458984 seconds
# (base) amadey@MacBook-Pro SenatorovDS % /Users/amadey/devwork/python/pypy3.11-v7.3.23-macos_arm64/bin/pypy3 python/performance_test.py
# Result: 49999995000000
# Execution time: 0.013547897338867188 seconds
# ```
#
# Сделайте вывод о разнице в производительности.
# - заупуск с pypy - вдвое быстрее
