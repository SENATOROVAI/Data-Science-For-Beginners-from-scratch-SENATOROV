# %%
"""lesson1.ipynb.
Краткое описание: Урок 1 — вводный пример (сложение, переменные и т.д.).
Автор: Otabek."""
# Out:
# 'lesson1.ipynb.\nКраткое описание: Урок 1 — вводный пример (сложение, переменные и т.д.).\nАвтор: Otabek.'

# %%
1 + 1 + 1
# Out:
# 3
